# %%
#CODEBOOK
#NETWORTH           Total net worth of household, 2016 dollars
#AGE                Age of head of household

#Data-Set: https://sda.berkeley.edu/sdaweb/analysis/?dataset=scfcomb

# %%
#import
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('sub-data.csv')
df.head()
#set x and y values
x = 'AGE'
y = 'NETWORTH'
#make scatterplot
plt.scatter(x = df[x], y=df[y])
plt.title('Networth By Age')
# Out:
# Text(0.5, 1.0, 'Networth By Age')
